# %%
import pandas as pd
import numpy

# %%
data = pd.read_csv('EpisodeTest.csv')

# %%
data.head()
# Out:
#    Bar Size      Directed by               Episode title     Guest star  \
# 0      1000       Wes Archer           "Homer's Odyssey"   Sam McMurray
# 1      1000       Wes Archer              "Moaning Lisa"     Ron Taylor
# 2      1000       Wes Archer  "The Call of the Simpsons"  Albert Brooks
# 3      1000  David Silverman     "Life on the Fast Lane"  Albert Brooks
# 4      1000       Rich Moore         "Homer's Night Out"   Sam McMurray
#
#    No. in Season  No. in Series      No.  Appearances Original air date  \
# 0              3              3  003–103            1           1/21/90
# 1              6              6  006–106            1           2/11/90
# 2              7              7  007–107            1           2/18/90
# 3              9              9  009–109            1           3/18/90
# 4             10             10  010–110            1           3/25/90
#
#   Production Code (Characters) Production Code               Role(s)  \
# ...

# %%
data.groupby(['Title'])['U.S. Viewers'].max()
# Out:
# Title
# "$pringfield (or, How I Learned to Stop Worrying and Love Legalized Gambling)"    17.9
# "'Round Springfield"                                                              12.6
# "'Scuse Me While I Miss the Sky"                                                  12.6
# "'Tis the Fifteenth Season"                                                        0.0
# "22 Short Films About Springfield"                                                10.5
# "24 Minutes"                                                                       9.8
# "500 Keys"                                                                         6.0
# "A Fish Called Selma"                                                             12.9
# "A Hunka Hunka Burns in Love"                                                      0.0
# "A Midsummer's Nice Dream"                                                         5.4
# "A Star Is Born-Again"                                                            14.4
# ...
